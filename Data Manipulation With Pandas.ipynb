# %%
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd

# %%
titanic_train = pd.read_csv("https://gist.githubusercontent.com/jwalsh/ce1dc0436aba5b7a5c9666f47fa5a380/raw/5ce3854392b43ff97907112d344fc008229b0445/titanic.csv")   
titanic_train
# Out:
#      PassengerId  Survived  Pclass         Lname  \
# 0              1         0       3        Braund
# 1              2         1       1       Cumings
# 2              3         1       3     Heikkinen
# 3              4         1       1      Futrelle
# 4              5         0       3         Allen
# ..           ...       ...     ...           ...
# 151          152         1       1         Pears
# 152          153         0       3           Meo
# 153          154         0       3  van Billiard
# 154          155         0       3         Olsen
# 155          156         0       1      Williams
#
#                                             Name     Sex   Age  SibSp  Parch  \
# 0                                Mr. Owen Harris    male  22.0      1      0
# 1     Mrs. John Bradley (Florence Briggs Thayer)  female  38.0      1      0
# 2                                    Miss. Laina  female  26.0      0      0
# ...

# %%
titanic_train.tail(10)
#Return the 10 records from last
# Out:
#      PassengerId  Survived  Pclass         Lname                         Name  \
# 146          147         1       3     Andersson            Mr. August Edvard
# 147          148         0       3          Ford          Miss. Robina Maggie
# 148          149         0       2      Navratil                   Mr. Michel
# 149          150         0       2         Byles   Rev. Thomas Roussel Davids
# 150          151         0       2       Bateman            Rev. Robert James
# 151          152         1       1         Pears   Mrs. Thomas (Edith Wearne)
# 152          153         0       3           Meo                  Mr. Alfonzo
# 153          154         0       3  van Billiard            Mr. Austin Blyler
# 154          155         0       3         Olsen               Mr. Ole Martin
# 155          156         0       1      Williams            Mr. Charles Duane
#
#         Sex   Age  SibSp  Parch       Ticket     Fare Cabin Embarked
# ...

# %%
titanic_train.head(10)
#Return the first 10 records
# Out:
#    PassengerId  Survived  Pclass      Lname  \
# 0            1         0       3     Braund
# 1            2         1       1    Cumings
# 2            3         1       3  Heikkinen
# 3            4         1       1   Futrelle
# 4            5         0       3      Allen
# 5            6         0       3      Moran
# 6            7         0       1   McCarthy
# 7            8         0       3    Palsson
# 8            9         1       3    Johnson
# 9           10         1       2     Nasser
#
#                                           Name     Sex   Age  SibSp  Parch  \
# 0                              Mr. Owen Harris    male  22.0      1      0
# 1   Mrs. John Bradley (Florence Briggs Thayer)  female  38.0      1      0
# 2                                  Miss. Laina  female  26.0      0      0
# 3           Mrs. Jacques Heath (Lily May Peel)  female  35.0      1      0
# 4                            Mr. William Henry    male  35.0      0      0
# ...

# %%
titanic_train.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Lname           object
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
titanic_train.Lname.astype(str)
#Here we converted the Object type to string
#Same as you can convert from pplace to another
#Note:- Object take more memory than string you we convert them in String
# Out:
# 0            Braund
# 1           Cumings
# 2         Heikkinen
# 3          Futrelle
# 4             Allen
#            ...
# 151           Pears
# 152             Meo
# 153    van Billiard
# 154           Olsen
# 155        Williams
# Name: Lname, Length: 156, dtype: object

# %%
ind=titanic_train.dtypes[titanic_train.dtypes==object].index
titanic_train[ind]
#Here we extracted all the column with datatype == object
# Out:
#             Lname                                         Name     Sex  \
# 0          Braund                              Mr. Owen Harris    male
# 1         Cumings   Mrs. John Bradley (Florence Briggs Thayer)  female
# 2       Heikkinen                                  Miss. Laina  female
# 3        Futrelle           Mrs. Jacques Heath (Lily May Peel)  female
# 4           Allen                            Mr. William Henry    male
# ..            ...                                          ...     ...
# 151         Pears                   Mrs. Thomas (Edith Wearne)  female
# 152           Meo                                  Mr. Alfonzo    male
# 153  van Billiard                            Mr. Austin Blyler    male
# 154         Olsen                               Mr. Ole Martin    male
# 155      Williams                            Mr. Charles Duane    male
#
#                Ticket Cabin Embarked
# 0           A/5 21171   NaN        S
# 1            PC 17599   C85        C
# ...

# %%
titanic_train.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   156.000000  156.000000  156.000000  126.000000  156.000000
# mean     78.500000    0.346154    2.423077   28.141508    0.615385
# std      45.177428    0.477275    0.795459   14.613880    1.056235
# min       1.000000    0.000000    1.000000    0.830000    0.000000
# 25%      39.750000    0.000000    2.000000   19.000000    0.000000
# 50%      78.500000    0.000000    3.000000   26.000000    0.000000
# 75%     117.250000    1.000000    3.000000   35.000000    1.000000
# max     156.000000    1.000000    3.000000   71.000000    5.000000
#
#             Parch        Fare
# count  156.000000  156.000000
# mean     0.397436   28.109587
# std      0.870146   39.401047
# min      0.000000    6.750000
# 25%      0.000000    8.003150
# 50%      0.000000   14.454200
# 75%      0.000000   30.371850
# max      5.000000  263.000000

# %%
titanic_train.Age.value_counts()
# Out:
# 21.00    8
# 22.00    6
# 29.00    6
# 19.00    6
# 24.00    5
# 28.00    5
# 26.00    4
# 38.00    4
# 20.00    4
# 34.00    3
# 16.00    3
# 17.00    3
# 18.00    3
# 33.00    3
# 23.00    3
# 14.00    3
# 35.00    3
# 2.00     3
# 27.00    3
# 47.00    2
# 25.00    2
# 54.00    2
# 32.00    2
# 45.00    2
# 37.00    2
# 40.00    2
# 4.00     2
# 42.00    2
# 51.00    2
# 32.50    2
# 14.50    1
# 9.00     1
# 71.00    1
# 59.00    1
# 46.00    1
# 55.50    1
# 70.50    1
# 36.50    1
# 12.00    1
# 65.00    1
# 30.00    1
# 0.83     1
# 11.00    1
# 5.00     1
# 28.50    1
# 49.00    1
# 7.00     1
# 3.00     1
# 66.00    1
# 8.00     1
# 15.00    1
# 31.00    1
# 55.00    1
# 39.00    1
# 58.00    1
# 40.50    1
# Name: Age, dtype: int64

# %%
titanic_train.columns
#Extracting the Columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Lname', 'Name', 'Sex', 'Age',
#        'SibSp', 'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
titanic_train[['PassengerId', 'Survived']]
# Out:
#      PassengerId  Survived
# 0              1         0
# 1              2         1
# 2              3         1
# 3              4         1
# 4              5         0
# ..           ...       ...
# 151          152         1
# 152          153         0
# 153          154         0
# 154          155         0
# 155          156         0
#
# [156 rows x 2 columns]

# %%
sorted(titanic_train["Name"])[0:10:2]
# Out:
# [' Don. Manuel E',
#  ' Master. Elias',
#  ' Master. Gerios',
#  ' Master. Harald',
#  ' Master. William Frederick']

# %%
titanic_train.describe(include="all")
# Out:
#         PassengerId    Survived      Pclass      Lname              Name  \
# count    156.000000  156.000000  156.000000        156               156
# unique          NaN         NaN         NaN        141               152
# top             NaN         NaN         NaN  Andersson   Miss. Elizabeth
# freq            NaN         NaN         NaN          4                 2
# mean      78.500000    0.346154    2.423077        NaN               NaN
# std       45.177428    0.477275    0.795459        NaN               NaN
# min        1.000000    0.000000    1.000000        NaN               NaN
# 25%       39.750000    0.000000    2.000000        NaN               NaN
# 50%       78.500000    0.000000    3.000000        NaN               NaN
# 75%      117.250000    1.000000    3.000000        NaN               NaN
# max      156.000000    1.000000    3.000000        NaN               NaN
#
#          Sex         Age       SibSp       Parch Ticket        Fare  \
# ...

# %%
pd.Categorical(titanic_train['Pclass'])
# Out:
# [3, 1, 3, 1, 3, ..., 1, 3, 3, 3, 1]
# Length: 156
# Categories (3, int64): [1, 2, 3]

# %%
titanic_train.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Lname           object
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
pd.Categorical(titanic_train['Pclass'])
# Out:
# [3, 1, 3, 1, 3, ..., 1, 3, 3, 3, 1]
# Length: 156
# Categories (3, int64): [1, 2, 3]

# %%
# Out:
#      PassengerId  Survived  Pclass         Lname  \
# 0              1         0       3        Braund
# 1              2         1       1       Cumings
# 2              3         1       3     Heikkinen
# 3              4         1       1      Futrelle
# 4              5         0       3         Allen
# ..           ...       ...     ...           ...
# 151          152         1       1         Pears
# 152          153         0       3           Meo
# 153          154         0       3  van Billiard
# 154          155         0       3         Olsen
# 155          156         0       1      Williams
#
#                                             Name     Sex   Age  SibSp  Parch  \
# 0                                Mr. Owen Harris    male  22.0      1      0
# 1     Mrs. John Bradley (Florence Briggs Thayer)  female  38.0      1      0
# 2                                    Miss. Laina  female  26.0      0      0
# ...

# %%
titanic_train['Pclass'] = pd.Categorical(titanic_train['Pclass'])

# %%
titanic_train['Pclass'].unique()
#It will give you unique value
# Out:
# [3, 1, 2]
# Categories (3, int64): [1, 2, 3]

# %%
titanic_train.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Lname            0
# Name             0
# Sex              0
# Age             30
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          125
# Embarked         1
# dtype: int64

# %%
titanic_train.notnull().sum()
# Out:
# PassengerId    156
# Survived       156
# Pclass         156
# Lname          156
# Name           156
# Sex            156
# Age            126
# SibSp          156
# Parch          156
# Ticket         156
# Fare           156
# Cabin           31
# Embarked       155
# dtype: int64

# %%
titanic_train.drop([0])
#Dropping from row
# Out:
#      PassengerId  Survived Pclass         Lname  \
# 1              2         1      1       Cumings
# 2              3         1      3     Heikkinen
# 3              4         1      1      Futrelle
# 4              5         0      3         Allen
# 5              6         0      3         Moran
# ..           ...       ...    ...           ...
# 151          152         1      1         Pears
# 152          153         0      3           Meo
# 153          154         0      3  van Billiard
# 154          155         0      3         Olsen
# 155          156         0      1      Williams
#
#                                             Name     Sex   Age  SibSp  Parch  \
# 1     Mrs. John Bradley (Florence Briggs Thayer)  female  38.0      1      0
# 2                                    Miss. Laina  female  26.0      0      0
# 3             Mrs. Jacques Heath (Lily May Peel)  female  35.0      1      0
# ...

# %%
titanic_train.drop(['Pclass'],axis=1)
# Out:
#      PassengerId  Survived         Lname  \
# 0              1         0        Braund
# 1              2         1       Cumings
# 2              3         1     Heikkinen
# 3              4         1      Futrelle
# 4              5         0         Allen
# ..           ...       ...           ...
# 151          152         1         Pears
# 152          153         0           Meo
# 153          154         0  van Billiard
# 154          155         0         Olsen
# 155          156         0      Williams
#
#                                             Name     Sex   Age  SibSp  Parch  \
# 0                                Mr. Owen Harris    male  22.0      1      0
# 1     Mrs. John Bradley (Florence Briggs Thayer)  female  38.0      1      0
# 2                                    Miss. Laina  female  26.0      0      0
# 3             Mrs. Jacques Heath (Lily May Peel)  female  35.0      1      0
# 4                              Mr. William Henry    male  35.0      0      0
# ...

# %%
titanic_train['Age'][titanic_train.Age.isnull()].index
# Out:
# Int64Index([  5,  17,  19,  26,  28,  29,  31,  32,  36,  42,  45,  46,  47,
#              48,  55,  64,  65,  76,  77,  82,  87,  95, 101, 107, 109, 121,
#             126, 128, 140, 154],
#            dtype='int64')
